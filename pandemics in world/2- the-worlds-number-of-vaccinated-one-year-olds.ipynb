# %%
import pandas as pd
df = pd.read_csv("2- the-worlds-number-of-vaccinated-one-year-olds.csv")
display(df)
# Out:
#             Entity Code  Year  Number of one-year-olds vaccinated with HepB3  \
# 0      Afghanistan  AFG  1980                                            NaN
# 1      Afghanistan  AFG  1981                                            NaN
# 2      Afghanistan  AFG  1982                                            NaN
# 3      Afghanistan  AFG  1983                                            NaN
# 4      Afghanistan  AFG  1984                                            NaN
# ...            ...  ...   ...                                            ...
# 10663     Zimbabwe  ZWE  2017                                       407106.0
# 10664     Zimbabwe  ZWE  2018                                       407252.0
# 10665     Zimbabwe  ZWE  2019                                       413773.0
# 10666     Zimbabwe  ZWE  2020                                       397858.0
# 10667     Zimbabwe  ZWE  2021                                       399964.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 12 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Entity                                                                        10668 non-null  object
#  1   Code                                                                          9954 non-null   object
#  2   Year                                                                          10668 non-null  int64
#  3   Number of one-year-olds vaccinated with HepB3                                 4214 non-null   float64
#  4   Number of one-year-olds vaccinated with DTP containing vaccine, 3rd dose      7602 non-null   float64
#  5   Number of one-year-olds vaccinated with polio, 3rd dose                       7603 non-null   float64
# ...

# %%
populacao=df["Population - Sex: all - Age: 0 - Variant: estimates"].dropna()
display(populacao)
# Out:
# 0        553827.0
# 1        493818.0
# 2        445673.0
# 3        439692.0
# 4        452788.0
#            ...
# 10663    464521.0
# 10664    466524.0
# 10665    468844.0
# 10666    470340.0
# 10667    472443.0
# Name: Population - Sex: all - Age: 0 - Variant: estimates, Length: 10668, dtype: float64

# %%
formatado = pd.set_option('display.float_format', lambda x: '%.3f' % x)
populacao.describe()
# Out:
# count       10668.000
# mean      3486283.571
# std      15577410.538
# min            25.000
# 25%          7323.500
# 50%         97100.500
# 75%        565935.000
# max     139783730.000
# Name: Population - Sex: all - Age: 0 - Variant: estimates, dtype: float64

# %%
limpodf.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 display(formatado)
#
# NameError: name 'formatado' is not defined
