# %%
import pandas as pd
df = pd.read_csv("1- the-number-of-cases-of-infectious-diseases.csv")
display(df)
# Out:
#             Entity Code  Year  Indicator:Number of cases of yaws reported  \
# 0      Afghanistan  AFG  1980                                         NaN
# 1      Afghanistan  AFG  1981                                         NaN
# 2      Afghanistan  AFG  1982                                         NaN
# 3      Afghanistan  AFG  1983                                         NaN
# 4      Afghanistan  AFG  1984                                         NaN
# ...            ...  ...   ...                                         ...
# 10516     Zimbabwe  ZWE  2022                                         NaN
# 10517     Zimbabwe  ZWE  1973                                         NaN
# 10518     Zimbabwe  ZWE  1974                                         NaN
# 10519     Zimbabwe  ZWE  1975                                         NaN
# 10520     Zimbabwe  ZWE  1976                                         NaN
#
#        Total (estimated) polio cases  \
# 0                             6160.0
# ...

# %%
df.reset_index(drop=True)
# Out:
#             Entity Code  Year  Indicator:Number of cases of yaws reported  \
# 0      Afghanistan  AFG  1980                                         NaN
# 1      Afghanistan  AFG  1981                                         NaN
# 2      Afghanistan  AFG  1982                                         NaN
# 3      Afghanistan  AFG  1983                                         NaN
# 4      Afghanistan  AFG  1984                                         NaN
# ...            ...  ...   ...                                         ...
# 10516     Zimbabwe  ZWE  2022                                         NaN
# 10517     Zimbabwe  ZWE  1973                                         NaN
# 10518     Zimbabwe  ZWE  1974                                         NaN
# 10519     Zimbabwe  ZWE  1975                                         NaN
# 10520     Zimbabwe  ZWE  1976                                         NaN
#
#        Total (estimated) polio cases  \
# 0                             6160.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10521 entries, 0 to 10520
# Data columns (total 12 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            10521 non-null  object
#  1   Code                                                              9393 non-null   object
#  2   Year                                                              10521 non-null  int64
#  3   Indicator:Number of cases of yaws reported                        74 non-null     float64
#  4   Total (estimated) polio cases                                     7610 non-null   float64
#  5   Reported cases of guinea worm disease in humans                   8428 non-null   float64
#  6   Number of new cases of rabies, in both sexes aged all ages        6780 non-null   float64
# ...

# %%
dff = df[['Entity','Number of new cases of rabies, in both sexes aged all ages','Number of new cases of malaria, in both sexes aged all ages','Number of new cases of hiv/aids, in both sexes aged all ages']]
display(dff)
# Out:
#             Entity  \
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# ...            ...
# 10516     Zimbabwe
# 10517     Zimbabwe
# 10518     Zimbabwe
# 10519     Zimbabwe
# 10520     Zimbabwe
#
#        Number of new cases of rabies, in both sexes aged all ages  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10516                                                NaN
# 10517                                                NaN
# 10518                                                NaN
# 10519                                                NaN
# 10520                                                NaN
#
# ...

# %%
limp = df.dropna()
limp
# Out:
#       Entity      Code  Year  Indicator:Number of cases of yaws reported  \
# 10273  World  OWID_WRL  2008                                     56223.0
# 10274  World  OWID_WRL  2009                                     69467.0
# 10275  World  OWID_WRL  2010                                     80226.0
# 10276  World  OWID_WRL  2011                                     51101.0
# 10277  World  OWID_WRL  2012                                     49375.0
# 10278  World  OWID_WRL  2013                                     58915.0
# 10279  World  OWID_WRL  2014                                     50584.0
# 10280  World  OWID_WRL  2015                                     46062.0
# 10281  World  OWID_WRL  2016                                     59307.0
#
#        Total (estimated) polio cases  \
# 10273                         1927.0
# 10274                         2020.0
# 10275                         1988.0
# 10276                          827.0
# 10277                          326.0
# ...

# %%
limp.describe()
# Out:
#               Year  Indicator:Number of cases of yaws reported  \
# count     9.000000                                    9.000000
# mean   2012.000000                                57917.777778
# std       2.738613                                10900.855755
# min    2008.000000                                46062.000000
# 25%    2010.000000                                50584.000000
# 50%    2012.000000                                56223.000000
# 75%    2014.000000                                59307.000000
# max    2016.000000                                80226.000000
#
#        Total (estimated) polio cases  \
# count                       9.000000
# mean                      923.555556
# std                       823.226140
# min                        49.000000
# 25%                       326.000000
# 50%                       565.000000
# 75%                      1927.000000
# max                      2020.000000
#
# ...

# %%
anal = limp[['Number of new cases of rabies, in both sexes aged all ages','Number of new cases of malaria, in both sexes aged all ages','Reported cases of guinea worm disease in humans']]
display(anal)
# Out:
#        Number of new cases of rabies, in both sexes aged all ages  \
# 10273                                          19018.432
# 10274                                          17927.213
# 10275                                          17215.896
# 10276                                          16723.320
# 10277                                          16141.489
# 10278                                          15555.730
# 10279                                          15056.748
# 10280                                          14742.936
# 10281                                          14498.030
#
#        Number of new cases of malaria, in both sexes aged all ages  \
# 10273                                        264005060.0
# 10274                                        263586460.0
# 10275                                        263746240.0
# 10276                                        260391280.0
# 10277                                        251017840.0
# ...

# %%
anal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 10273 to 10281
# Data columns (total 3 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Number of new cases of rabies, in both sexes aged all ages   9 non-null      float64
#  1   Number of new cases of malaria, in both sexes aged all ages  9 non-null      float64
#  2   Reported cases of guinea worm disease in humans              9 non-null      float64
# dtypes: float64(3)
# memory usage: 588.0 bytes

# %%
limp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 10273 to 10281
# Data columns (total 12 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            9 non-null      object
#  1   Code                                                              9 non-null      object
#  2   Year                                                              9 non-null      int64
#  3   Indicator:Number of cases of yaws reported                        9 non-null      float64
#  4   Total (estimated) polio cases                                     9 non-null      float64
#  5   Reported cases of guinea worm disease in humans                   9 non-null      float64
#  6   Number of new cases of rabies, in both sexes aged all ages        9 non-null      float64
# ...

# %%
dflimpo = dff.dropna()
display(dflimpo)
# Out:
#             Entity  \
# 10     Afghanistan
# 11     Afghanistan
# 12     Afghanistan
# 13     Afghanistan
# 14     Afghanistan
# ...            ...
# 10509     Zimbabwe
# 10510     Zimbabwe
# 10511     Zimbabwe
# 10512     Zimbabwe
# 10513     Zimbabwe
#
#        Number of new cases of rabies, in both sexes aged all ages  \
# 10                                              2.145772
# 11                                              2.320975
# 12                                              3.126361
# 13                                              3.446122
# 14                                              3.557025
# ...                                                  ...
# 10509                                          21.351868
# 10510                                          22.006933
# 10511                                          22.744210
# 10512                                          22.990591
# 10513                                          23.040785
#
# ...

# %%
dflimpo.iloc[:5].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
por = dflimpo.describe().style.format("{:.0%}")
display(por)
# Out:
# <style type="text/css">
# </style>
# <table id="T_53d36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53d36_level0_col0" class="col_heading level0 col0" >Number of new cases of rabies, in both sexes aged all ages</th>
#       <th id="T_53d36_level0_col1" class="col_heading level0 col1" >Number of new cases of malaria, in both sexes aged all ages</th>
#       <th id="T_53d36_level0_col2" class="col_heading level0 col2" >Number of new cases of hiv/aids, in both sexes aged all ages</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53d36_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_53d36_row0_col0" class="data row0 col0" >678000%</td>
#       <td id="T_53d36_row0_col1" class="data row0 col1" >678000%</td>
#       <td id="T_53d36_row0_col2" class="data row0 col2" >678000%</td>
#     </tr>
#     <tr>
#       <th id="T_53d36_level0_row1" class="row_heading level0 row1" >mean</th>
# ...

# %%
dflimpo[['Entity','Number of new cases of rabies, in both sexes aged all ages','Number of new cases of malaria, in both sexes aged all ages','Number of new cases of hiv/aids, in both sexes aged all ages']].iloc[:20].plot.bar()
# Out:
# <Axes: >
